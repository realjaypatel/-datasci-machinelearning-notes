# %%
import seaborn as sns
tips = sns.load_dataset('tips')

# %%
sns.set_style()#white,ticks,darkgrid,whitegrid
sns.countplot(x='sex',data=tips)
sns.despine(left=True,bottom=True)#remove top spine and right spine
#you can use matplot lib knowledge, plt.figure(figsize=(12,3))
#if you are preparing for any other thing like poster
# sns.set_context('poster',font_scale=3)#notebook



sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex')
#pallete='coolworm' you can go to matplotlib/colormap and change you pallete to those you want
# Out:
# d:\anaconda\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# d:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 10
#       3 sns.despine(left=True,bottom=True)#remove top spine and right spine
#       4 #you can use matplot lib knowledge, plt.figure(figsize=(12,3))
#       5 #if you are preparing for any other thing like poster
#       6 # sns.set_context('poster',font_scale=3)#notebook
# ---> 10 sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex')
#
# File d:\anaconda\Lib\site-packages\seaborn\regression.py:640, in lmplot(data, x, y, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws)
#     638 # Add a legend
#     639 if legend and (hue is not None) and (hue not in [col, row]):
# --> 640     facets.add_legend()
#     641 return facets
#
# File d:\anaconda\Lib\site-packages\seaborn\axisgrid.py:208, in Grid.add_legend(self, legend_data, title, label_order, adjust_subtitles, **kwargs)
#     205     right = 1 - self._space_needed
#     207     # Place the subplot axes to give space for the legend
# --> 208     self._figure.subplots_adjust(right=right)
#     209     self._tight_layout_rect[2] = right
#     211 else:
#     212     # Draw a legend in the first axis
#
# File d:\anaconda\Lib\site-packages\matplotlib\figure.py:1351, in FigureBase.subplots_adjust(self, left, bottom, right, top, wspace, hspace)
#    1346     _api.warn_external(
#    1347         "This figure was using a layout engine that is "
#    1348         "incompatible with subplots_adjust and/or tight_layout; "
#    1349         "not calling subplots_adjust.")
#    1350     return
# -> 1351 self.subplotpars.update(left, bottom, right, top, wspace, hspace)
#    1352 for ax in self.axes:
#    1353     if ax.get_subplotspec() is not None:
#
# File d:\anaconda\Lib\site-packages\matplotlib\figure.py:163, in SubplotParams.update(self, left, bottom, right, top, wspace, hspace)
#     158 """
#     159 Update the dimensions of the passed parameters. *None* means unchanged.
#     160 """
#     161 if ((left if left is not None else self.left)
#     162         >= (right if right is not None else self.right)):
# --> 163     raise ValueError('left cannot be >= right')
#     164 if ((bottom if bottom is not None else self.bottom)
#     165         >= (top if top is not None else self.top)):
#     166     raise ValueError('bottom cannot be >= top')
#
# ValueError: left cannot be >= right
